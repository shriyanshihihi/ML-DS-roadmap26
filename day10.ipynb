# %%
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

X, y = load_breast_cancer(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = LogisticRegression(max_iter=500)
model.fit(X_train, y_train)  


# For binary Logistic Regression, predict_proba() returns two probabilities per sample:
# [P(y = 0 | x),  P(y = 1 | x)]

probs = model.predict_proba(X_test)[:5]
probs
# Out:
# c:\Users\Garod\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# array([[9.99992297e-01, 7.70300629e-06],
#        [1.59527148e-03, 9.98404729e-01],
#        [1.00000000e+00, 1.46015713e-10],
#        [1.00000000e+00, 5.50280631e-11],
#        [6.58790368e-03, 9.93412096e-01]])

# %% [markdown]
# uses sigmoid function

# %% [markdown]
# Logistic Regression does not directly predict class labels.
# It predicts probabilities, and class labels are decided after thresholding.
#
# This is why it’s called a probabilistic classifier.

# %% [markdown]
# Business & product decisions
#
# Example: Loan approval
#
# Predicting default
#
# False Positive → reject good customer
#
# False Negative → give loan to defaulter (huge loss)
#
# Depending on business strategy:
#
# Conservative bank → threshold ↑
#
# Aggressive growth → threshold ↓
#
# 👉 Threshold is a business decision, not a model decision

# %% [markdown]
# By adjusting the threshold, we can trade precision for recall and align the model’s behavior with business or domain requirements.
